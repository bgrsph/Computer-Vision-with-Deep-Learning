# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from comp451.classifiers.neural_net import ThreeLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `ThreeLayerNet` in the file `comp451/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return ThreeLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `comp451/classifiers/neural_net.py` and look at the method `ThreeLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.03596154, -0.01613583, -0.00048556],
  [-0.09480192, 0.20724618, -0.09763798],
  [-0.07015667, 0.17081869, -0.07675745],
  [ 0.01473052, 0.09321097, -0.0395178 ],
  [-0.05306489, 0.04729807,  0.01750587]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.03596154 -0.01613583 -0.00048556]
#  [-0.09480192  0.20724618 -0.09763798]
#  [-0.07015667  0.17081869 -0.07675745]
#  [ 0.01473052  0.09321097 -0.0395178 ]
#  [-0.05306489  0.04729807  0.01750587]]
#
# correct scores:
# [[-0.03596154 -0.01613583 -0.00048556]
#  [-0.09480192  0.20724618 -0.09763798]
#  [-0.07015667  0.17081869 -0.07675745]
#  [ 0.01473052  0.09321097 -0.0395178 ]
#  [-0.05306489  0.04729807  0.01750587]]
#
# Difference between your scores and correct scores:
# 4.807962379632267e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularization loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.1760667703015604

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 0.0

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, `b2`, `W3` and `b3`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from comp451.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, W3, b1, b2 and b3.
regp = 0.5
loss, grads = net.loss(X, y, reg=regp)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=regp)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W3 max relative error: 3.417395e-10
# b3 max relative error: 8.494175e-11
# W2 max relative error: 1.692191e-09
# b2 max relative error: 4.590212e-10
# W1 max relative error: 1.262267e-09
# b1 max relative error: 7.670388e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `ThreeLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `ThreeLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a three-layer network on toy data. You should achieve a training loss less than 0.21.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.20626818306089362

# %% [markdown]
# # Load the data
# Now that you have implemented a three-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from comp451.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the three-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'comp451/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
np.random.seed(1)
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = ThreeLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-2, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.341590
# iteration 100 / 1000: loss 2.317463
# iteration 200 / 1000: loss 2.307715
# iteration 300 / 1000: loss 2.304181
# iteration 400 / 1000: loss 2.138494
# iteration 500 / 1000: loss 2.124073
# iteration 600 / 1000: loss 2.208880
# iteration 700 / 1000: loss 2.154583
# iteration 800 / 1000: loss 2.076965
# iteration 900 / 1000: loss 2.014032
# Validation accuracy:  0.307

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.307 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Classification accuracy')
plt.legend()
plt.show()

# %%
from comp451.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 50% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can (50% could serve as a reference), with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %% [markdown]
# **Explain your hyperparameter tuning process below.**
#
# $\color{blue}{\textit Your Answer:}$ *I've used a grip search for hyperparameter tuning. Since learning rate is possibly too low, I've add an increasing sequence. Also I wanted to see how big can the model get, so I've add multiple sizes. Since gradient descent is essential, I put num_epochs as a hyper-parameter as well. When I initiated the grid-search with highly large learning rates, I've seen that the validation accuracy has significantly dropped, so I've tried 3 learning rates which are popular choices for most of the neural networks.Best model has 0.53 validation accuracy and 0.522 testing accuracy. Hyper-params: (lr: 0.01, reg: 1e-05, batch: 400, hidden: 150,epoch: 1500)*

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Best model has 0.53 validation accuracy. Hyper-params: (lr: 0.01, reg: 1e-05, batch: 400, hidden: 150,epoch: 1500) 
# Define the hyper-parameter lists for iteration
learning_rates = [1e-2,1e-3,1e-4]
regularization_strengths = [1e-1, 1e-4, 1e-5]
batch_sizes = [300, 400]
hidden_layer_sizes = [50, 90, 150]
num_epochs = [1000, 1500]

# define the grid search variable for easy scripting
grid_search = [ (lr,rs,batch_size, hidden_size, epochs) for lr in learning_rates for rs in regularization_strengths
               for batch_size in batch_sizes for hidden_size in hidden_layer_sizes for epochs in num_epochs]

# results: {[array of hyper-params], {training accuracy, validation accuracy}}
results = {} 
i = 0
best_val = -1
for (lr,rs,batch_size, hidden_size, epochs) in grid_search:
    # Keep the iteration
    i += 1
    # Create a new network
    net = ThreeLayerNet(input_size, hidden_size, num_classes)
    # Train the network
    stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=epochs, batch_size=batch_size,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=rs, verbose=False)
    
    # Predict on the validation set
    val_acc = (net.predict(X_val) == y_val).mean()
    # Get the training accuracy
    train_acc = (net.predict(X_train) == y_train).mean()
    # Store the hyper-parameters and results in the results dict.
    results[(lr, rs, batch_size, hidden_size, epochs)] = (train_acc, val_acc)
    # Store the model with the best validation accuracy
    if best_val < val_acc:
        best_val = val_acc
        best_net = net
    # Print information
    print("[SEARCH ", i, "] Training Accuracy: ", train_acc, "  Validation Accuracy: ", val_acc)
    print("Hyper-parameters: ", (lr, rs, batch_size, hidden_size, epochs), "\n")
    
    

#Print final information about the best model
print("Best model has the validation accuracy of " , best_val)

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# [SEARCH  1 ] Training Accuracy:  0.44120408163265307   Validation Accuracy:  0.456
# Hyper-parameters:  (0.01, 0.1, 300, 50, 1000)
#
# [SEARCH  2 ] Training Accuracy:  0.47148979591836737   Validation Accuracy:  0.468
# Hyper-parameters:  (0.01, 0.1, 300, 50, 1500)
#
# [SEARCH  3 ] Training Accuracy:  0.442   Validation Accuracy:  0.458
# Hyper-parameters:  (0.01, 0.1, 300, 90, 1000)
#
# [SEARCH  4 ] Training Accuracy:  0.4888571428571429   Validation Accuracy:  0.485
# Hyper-parameters:  (0.01, 0.1, 300, 90, 1500)
#
# [SEARCH  5 ] Training Accuracy:  0.46948979591836737   Validation Accuracy:  0.448
# Hyper-parameters:  (0.01, 0.1, 300, 150, 1000)
#
# [SEARCH  6 ] Training Accuracy:  0.48820408163265305   Validation Accuracy:  0.481
# Hyper-parameters:  (0.01, 0.1, 300, 150, 1500)
#
# [SEARCH  7 ] Training Accuracy:  0.4299183673469388   Validation Accuracy:  0.428
# Hyper-parameters:  (0.01, 0.1, 400, 50, 1000)
#
# [SEARCH  8 ] Training Accuracy:  0.481   Validation Accuracy:  0.474
# Hyper-parameters:  (0.01, 0.1, 400, 50, 1500)
#
# [SEARCH  9 ] Training Accuracy:  0.47606122448979593   Validation Accuracy:  0.468
# Hyper-parameters:  (0.01, 0.1, 400, 90, 1000)
#
# [SEARCH  10 ] Training Accuracy:  0.4977551020408163   Validation Accuracy:  0.49
# Hyper-parameters:  (0.01, 0.1, 400, 90, 1500)
#
# [SEARCH  11 ] Training Accuracy:  0.4779387755102041   Validation Accuracy:  0.463
# Hyper-parameters:  (0.01, 0.1, 400, 150, 1000)
#
# [SEARCH  12 ] Training Accuracy:  0.5169387755102041   Validation Accuracy:  0.477
# Hyper-parameters:  (0.01, 0.1, 400, 150, 1500)
#
# [SEARCH  13 ] Training Accuracy:  0.4727959183673469   Validation Accuracy:  0.469
# Hyper-parameters:  (0.01, 0.0001, 300, 50, 1000)
#
# [SEARCH  14 ] Training Accuracy:  0.5249183673469388   Validation Accuracy:  0.501
# Hyper-parameters:  (0.01, 0.0001, 300, 50, 1500)
#
# [SEARCH  15 ] Training Accuracy:  0.5073061224489795   Validation Accuracy:  0.488
# Hyper-parameters:  (0.01, 0.0001, 300, 90, 1000)
#
# [SEARCH  16 ] Training Accuracy:  0.5540612244897959   Validation Accuracy:  0.517
# Hyper-parameters:  (0.01, 0.0001, 300, 90, 1500)
#
# [SEARCH  17 ] Training Accuracy:  0.514061224489796   Validation Accuracy:  0.494
# Hyper-parameters:  (0.01, 0.0001, 300, 150, 1000)
#
# [SEARCH  18 ] Training Accuracy:  0.5643673469387755   Validation Accuracy:  0.515
# Hyper-parameters:  (0.01, 0.0001, 300, 150, 1500)
#
# [SEARCH  19 ] Training Accuracy:  0.48759183673469386   Validation Accuracy:  0.477
# Hyper-parameters:  (0.01, 0.0001, 400, 50, 1000)
#
# [SEARCH  20 ] Training Accuracy:  0.5298163265306123   Validation Accuracy:  0.496
# Hyper-parameters:  (0.01, 0.0001, 400, 50, 1500)
#
# [SEARCH  21 ] Training Accuracy:  0.5125714285714286   Validation Accuracy:  0.482
# Hyper-parameters:  (0.01, 0.0001, 400, 90, 1000)
#
# [SEARCH  22 ] Training Accuracy:  0.5413061224489796   Validation Accuracy:  0.491
# Hyper-parameters:  (0.01, 0.0001, 400, 90, 1500)
#
# [SEARCH  23 ] Training Accuracy:  0.5292448979591837   Validation Accuracy:  0.496
# Hyper-parameters:  (0.01, 0.0001, 400, 150, 1000)
#
# [SEARCH  24 ] Training Accuracy:  0.5711224489795919   Validation Accuracy:  0.516
# Hyper-parameters:  (0.01, 0.0001, 400, 150, 1500)
#
# [SEARCH  25 ] Training Accuracy:  0.4719387755102041   Validation Accuracy:  0.456
# Hyper-parameters:  (0.01, 1e-05, 300, 50, 1000)
#
# [SEARCH  26 ] Training Accuracy:  0.5173469387755102   Validation Accuracy:  0.482
# Hyper-parameters:  (0.01, 1e-05, 300, 50, 1500)
#
# [SEARCH  27 ] Training Accuracy:  0.5143469387755102   Validation Accuracy:  0.496
# Hyper-parameters:  (0.01, 1e-05, 300, 90, 1000)
#
# [SEARCH  28 ] Training Accuracy:  0.5436734693877551   Validation Accuracy:  0.488
# Hyper-parameters:  (0.01, 1e-05, 300, 90, 1500)
#
# [SEARCH  29 ] Training Accuracy:  0.5153673469387755   Validation Accuracy:  0.495
# Hyper-parameters:  (0.01, 1e-05, 300, 150, 1000)
#
# [SEARCH  30 ] Training Accuracy:  0.5727142857142857   Validation Accuracy:  0.502
# Hyper-parameters:  (0.01, 1e-05, 300, 150, 1500)
#
# [SEARCH  31 ] Training Accuracy:  0.47455102040816327   Validation Accuracy:  0.468
# Hyper-parameters:  (0.01, 1e-05, 400, 50, 1000)
#
# [SEARCH  32 ] Training Accuracy:  0.5131020408163265   Validation Accuracy:  0.488
# Hyper-parameters:  (0.01, 1e-05, 400, 50, 1500)
#
# [SEARCH  33 ] Training Accuracy:  0.5033469387755102   Validation Accuracy:  0.49
# Hyper-parameters:  (0.01, 1e-05, 400, 90, 1000)
#
# [SEARCH  34 ] Training Accuracy:  0.5209183673469387   Validation Accuracy:  0.465
# Hyper-parameters:  (0.01, 1e-05, 400, 90, 1500)
#
# [SEARCH  35 ] Training Accuracy:  0.5353877551020408   Validation Accuracy:  0.502
# Hyper-parameters:  (0.01, 1e-05, 400, 150, 1000)
#
# [SEARCH  36 ] Training Accuracy:  0.5871224489795919   Validation Accuracy:  0.53
# Hyper-parameters:  (0.01, 1e-05, 400, 150, 1500)
#
# [SEARCH  37 ] Training Accuracy:  0.11624489795918368   Validation Accuracy:  0.1
# Hyper-parameters:  (0.001, 0.1, 300, 50, 1000)
#
# [SEARCH  38 ] Training Accuracy:  0.17820408163265306   Validation Accuracy:  0.158
# Hyper-parameters:  (0.001, 0.1, 300, 50, 1500)
#
# [SEARCH  39 ] Training Accuracy:  0.156265306122449   Validation Accuracy:  0.15
# Hyper-parameters:  (0.001, 0.1, 300, 90, 1000)
#
# [SEARCH  40 ] Training Accuracy:  0.1633673469387755   Validation Accuracy:  0.18
# Hyper-parameters:  (0.001, 0.1, 300, 90, 1500)
#
# [SEARCH  41 ] Training Accuracy:  0.20638775510204083   Validation Accuracy:  0.196
# Hyper-parameters:  (0.001, 0.1, 300, 150, 1000)
#
# [SEARCH  42 ] Training Accuracy:  0.17710204081632652   Validation Accuracy:  0.19
# Hyper-parameters:  (0.001, 0.1, 300, 150, 1500)
#
# [SEARCH  43 ] Training Accuracy:  0.10026530612244898   Validation Accuracy:  0.087
# Hyper-parameters:  (0.001, 0.1, 400, 50, 1000)
#
# [SEARCH  44 ] Training Accuracy:  0.11761224489795918   Validation Accuracy:  0.105
# Hyper-parameters:  (0.001, 0.1, 400, 50, 1500)
#
# [SEARCH  45 ] Training Accuracy:  0.1850408163265306   Validation Accuracy:  0.164
# Hyper-parameters:  (0.001, 0.1, 400, 90, 1000)
#
# [SEARCH  46 ] Training Accuracy:  0.1553877551020408   Validation Accuracy:  0.172
# Hyper-parameters:  (0.001, 0.1, 400, 90, 1500)
#
# [SEARCH  47 ] Training Accuracy:  0.17261224489795918   Validation Accuracy:  0.182
# Hyper-parameters:  (0.001, 0.1, 400, 150, 1000)
#
# [SEARCH  48 ] Training Accuracy:  0.1693265306122449   Validation Accuracy:  0.184
# Hyper-parameters:  (0.001, 0.1, 400, 150, 1500)
#
# [SEARCH  49 ] Training Accuracy:  0.12648979591836734   Validation Accuracy:  0.122
# Hyper-parameters:  (0.001, 0.0001, 300, 50, 1000)
#
# [SEARCH  50 ] Training Accuracy:  0.14646938775510204   Validation Accuracy:  0.14
# Hyper-parameters:  (0.001, 0.0001, 300, 50, 1500)
#
# [SEARCH  51 ] Training Accuracy:  0.16218367346938775   Validation Accuracy:  0.148
# Hyper-parameters:  (0.001, 0.0001, 300, 90, 1000)
#
# [SEARCH  52 ] Training Accuracy:  0.1724081632653061   Validation Accuracy:  0.185
# Hyper-parameters:  (0.001, 0.0001, 300, 90, 1500)
#
# [SEARCH  53 ] Training Accuracy:  0.1590408163265306   Validation Accuracy:  0.15
# Hyper-parameters:  (0.001, 0.0001, 300, 150, 1000)
#
# [SEARCH  54 ] Training Accuracy:  0.20791836734693878   Validation Accuracy:  0.218
# Hyper-parameters:  (0.001, 0.0001, 300, 150, 1500)
#
# [SEARCH  55 ] Training Accuracy:  0.1480408163265306   Validation Accuracy:  0.117
# Hyper-parameters:  (0.001, 0.0001, 400, 50, 1000)
#
# [SEARCH  56 ] Training Accuracy:  0.18691836734693879   Validation Accuracy:  0.181
# Hyper-parameters:  (0.001, 0.0001, 400, 50, 1500)
#
# [SEARCH  57 ] Training Accuracy:  0.15740816326530613   Validation Accuracy:  0.152
# Hyper-parameters:  (0.001, 0.0001, 400, 90, 1000)
#
# [SEARCH  58 ] Training Accuracy:  0.16179591836734694   Validation Accuracy:  0.173
# Hyper-parameters:  (0.001, 0.0001, 400, 90, 1500)
#
# [SEARCH  59 ] Training Accuracy:  0.162265306122449   Validation Accuracy:  0.156
# Hyper-parameters:  (0.001, 0.0001, 400, 150, 1000)
#
# [SEARCH  60 ] Training Accuracy:  0.17624489795918366   Validation Accuracy:  0.193
# Hyper-parameters:  (0.001, 0.0001, 400, 150, 1500)
#
# [SEARCH  61 ] Training Accuracy:  0.10046938775510204   Validation Accuracy:  0.078
# Hyper-parameters:  (0.001, 1e-05, 300, 50, 1000)
#
# [SEARCH  62 ] Training Accuracy:  0.155   Validation Accuracy:  0.146
# Hyper-parameters:  (0.001, 1e-05, 300, 50, 1500)
# [SEARCH  63 ] Training Accuracy:  0.16795918367346938   Validation Accuracy:  0.156
# Hyper-parameters:  (0.001, 1e-05, 300, 90, 1000)
#
# [SEARCH  64 ] Training Accuracy:  0.17640816326530612   Validation Accuracy:  0.189
# Hyper-parameters:  (0.001, 1e-05, 300, 90, 1500)
#
# [SEARCH  65 ] Training Accuracy:  0.1896938775510204   Validation Accuracy:  0.195
# Hyper-parameters:  (0.001, 1e-05, 300, 150, 1000)
#
# [SEARCH  66 ] Training Accuracy:  0.20661224489795918   Validation Accuracy:  0.217
# Hyper-parameters:  (0.001, 1e-05, 300, 150, 1500)
#
# [SEARCH  67 ] Training Accuracy:  0.13357142857142856   Validation Accuracy:  0.122
# Hyper-parameters:  (0.001, 1e-05, 400, 50, 1000)
#
# [SEARCH  68 ] Training Accuracy:  0.18348979591836734   Validation Accuracy:  0.177
# Hyper-parameters:  (0.001, 1e-05, 400, 50, 1500)
#
# [SEARCH  69 ] Training Accuracy:  0.18577551020408165   Validation Accuracy:  0.184
# Hyper-parameters:  (0.001, 1e-05, 400, 90, 1000)
#
# [SEARCH  70 ] Training Accuracy:  0.1626938775510204   Validation Accuracy:  0.18
# Hyper-parameters:  (0.001, 1e-05, 400, 90, 1500)
#
# [SEARCH  71 ] Training Accuracy:  0.18079591836734693   Validation Accuracy:  0.161
# Hyper-parameters:  (0.001, 1e-05, 400, 150, 1000)
#
# [SEARCH  72 ] Training Accuracy:  0.18281632653061225   Validation Accuracy:  0.195
# Hyper-parameters:  (0.001, 1e-05, 400, 150, 1500)
#
# [SEARCH  73 ] Training Accuracy:  0.13708163265306123   Validation Accuracy:  0.135
# Hyper-parameters:  (0.0001, 0.1, 300, 50, 1000)
#
# [SEARCH  74 ] Training Accuracy:  0.12359183673469387   Validation Accuracy:  0.1
# Hyper-parameters:  (0.0001, 0.1, 300, 50, 1500)
#
# [SEARCH  75 ] Training Accuracy:  0.14479591836734693   Validation Accuracy:  0.131
# Hyper-parameters:  (0.0001, 0.1, 300, 90, 1000)
#
# [SEARCH  76 ] Training Accuracy:  0.12285714285714286   Validation Accuracy:  0.11
# Hyper-parameters:  (0.0001, 0.1, 300, 90, 1500)
#
# [SEARCH  77 ] Training Accuracy:  0.12385714285714286   Validation Accuracy:  0.118
# Hyper-parameters:  (0.0001, 0.1, 300, 150, 1000)
#
# [SEARCH  78 ] Training Accuracy:  0.1674081632653061   Validation Accuracy:  0.192
# Hyper-parameters:  (0.0001, 0.1, 300, 150, 1500)
#
# [SEARCH  79 ] Training Accuracy:  0.0969795918367347   Validation Accuracy:  0.102
# Hyper-parameters:  (0.0001, 0.1, 400, 50, 1000)
#
# [SEARCH  80 ] Training Accuracy:  0.12246938775510204   Validation Accuracy:  0.12
# Hyper-parameters:  (0.0001, 0.1, 400, 50, 1500)
#
# [SEARCH  81 ] Training Accuracy:  0.1240204081632653   Validation Accuracy:  0.116
# Hyper-parameters:  (0.0001, 0.1, 400, 90, 1000)
#
# [SEARCH  82 ] Training Accuracy:  0.13228571428571428   Validation Accuracy:  0.133
# Hyper-parameters:  (0.0001, 0.1, 400, 90, 1500)
#
# [SEARCH  83 ] Training Accuracy:  0.16593877551020408   Validation Accuracy:  0.15
# Hyper-parameters:  (0.0001, 0.1, 400, 150, 1000)
#
# [SEARCH  84 ] Training Accuracy:  0.1420204081632653   Validation Accuracy:  0.159
# Hyper-parameters:  (0.0001, 0.1, 400, 150, 1500)
#
# [SEARCH  85 ] Training Accuracy:  0.10222448979591836   Validation Accuracy:  0.103
# Hyper-parameters:  (0.0001, 0.0001, 300, 50, 1000)
#
# [SEARCH  86 ] Training Accuracy:  0.11006122448979593   Validation Accuracy:  0.092
# Hyper-parameters:  (0.0001, 0.0001, 300, 50, 1500)
#
# [SEARCH  87 ] Training Accuracy:  0.10722448979591837   Validation Accuracy:  0.112
# Hyper-parameters:  (0.0001, 0.0001, 300, 90, 1000)
#
# [SEARCH  88 ] Training Accuracy:  0.126734693877551   Validation Accuracy:  0.111
# Hyper-parameters:  (0.0001, 0.0001, 300, 90, 1500)
#
# [SEARCH  89 ] Training Accuracy:  0.13420408163265307   Validation Accuracy:  0.135
# Hyper-parameters:  (0.0001, 0.0001, 300, 150, 1000)
#
# [SEARCH  90 ] Training Accuracy:  0.15340816326530612   Validation Accuracy:  0.152
# Hyper-parameters:  (0.0001, 0.0001, 300, 150, 1500)
#
# [SEARCH  91 ] Training Accuracy:  0.11869387755102041   Validation Accuracy:  0.123
# Hyper-parameters:  (0.0001, 0.0001, 400, 50, 1000)
#
# [SEARCH  92 ] Training Accuracy:  0.10642857142857143   Validation Accuracy:  0.098
# Hyper-parameters:  (0.0001, 0.0001, 400, 50, 1500)
#
# [SEARCH  93 ] Training Accuracy:  0.1276122448979592   Validation Accuracy:  0.131
# Hyper-parameters:  (0.0001, 0.0001, 400, 90, 1000)
#
# [SEARCH  94 ] Training Accuracy:  0.12481632653061224   Validation Accuracy:  0.143
# Hyper-parameters:  (0.0001, 0.0001, 400, 90, 1500)
#
# [SEARCH  95 ] Training Accuracy:  0.1346326530612245   Validation Accuracy:  0.158
# Hyper-parameters:  (0.0001, 0.0001, 400, 150, 1000)
#
# [SEARCH  96 ] Training Accuracy:  0.162   Validation Accuracy:  0.15
# Hyper-parameters:  (0.0001, 0.0001, 400, 150, 1500)
#
# [SEARCH  97 ] Training Accuracy:  0.09844897959183674   Validation Accuracy:  0.109
# Hyper-parameters:  (0.0001, 1e-05, 300, 50, 1000)
#
# [SEARCH  98 ] Training Accuracy:  0.11877551020408163   Validation Accuracy:  0.095
# Hyper-parameters:  (0.0001, 1e-05, 300, 50, 1500)
#
# [SEARCH  99 ] Training Accuracy:  0.13008163265306122   Validation Accuracy:  0.141
# Hyper-parameters:  (0.0001, 1e-05, 300, 90, 1000)
#
# [SEARCH  100 ] Training Accuracy:  0.1353469387755102   Validation Accuracy:  0.144
# Hyper-parameters:  (0.0001, 1e-05, 300, 90, 1500)
#
# [SEARCH  101 ] Training Accuracy:  0.14177551020408163   Validation Accuracy:  0.164
# Hyper-parameters:  (0.0001, 1e-05, 300, 150, 1000)
#
# [SEARCH  102 ] Training Accuracy:  0.17522448979591837   Validation Accuracy:  0.163
# Hyper-parameters:  (0.0001, 1e-05, 300, 150, 1500)
#
# [SEARCH  103 ] Training Accuracy:  0.09808163265306122   Validation Accuracy:  0.102
# Hyper-parameters:  (0.0001, 1e-05, 400, 50, 1000)
#
# [SEARCH  104 ] Training Accuracy:  0.102   Validation Accuracy:  0.08
# Hyper-parameters:  (0.0001, 1e-05, 400, 50, 1500)
#
# [SEARCH  105 ] Training Accuracy:  0.11640816326530612   Validation Accuracy:  0.117
# Hyper-parameters:  (0.0001, 1e-05, 400, 90, 1000)
#
# [SEARCH  106 ] Training Accuracy:  0.15953061224489795   Validation Accuracy:  0.148
# Hyper-parameters:  (0.0001, 1e-05, 400, 90, 1500)
#
# [SEARCH  107 ] Training Accuracy:  0.14457142857142857   Validation Accuracy:  0.146
# Hyper-parameters:  (0.0001, 1e-05, 400, 150, 1000)
#
# [SEARCH  108 ] Training Accuracy:  0.1453469387755102   Validation Accuracy:  0.137
# Hyper-parameters:  (0.0001, 1e-05, 400, 150, 1500)
#
# Best model has the validation accuracy of  0.53

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.522

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# $\color{blue}{\textit Your Answer:}$ 1,3
#
# $\color{blue}{\textit Your Explanation:}$ 1: Training on a larger dataset decreases the chance of overfitting, hence lower this gap. 2: Adding more units may result in overfitting at the current dataset since it has already have the potential to memorize the train data. 3: True. Since training is unsually high, increasing the regularization strength for making our model more realistic, i.e. more error prone, will decrease training accuracy.
